# %% [markdown]
# <a href="https://colab.research.google.com/github/soyeon0924/ML_class/blob/main/2_dataframe_operations_ml_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DataFrame Operations
#
# ## About the Data
# In this notebook, we will be working with 2 datasets:
# - Facebook's stock price throughout 2018 (obtained using the [`stock_analysis` package](https://github.com/stefmolin/stock-analysis)).
# - Daily weather data for NYC from the [National Centers for Environmental Information (NCEI) API](https://www.ncdc.noaa.gov/cdo-web/webservices/v2).
#
# *Note: The NCEI is part of the National Oceanic and Atmospheric Administration (NOAA) and, as you can see from the URL for the API, this resource was created when the NCEI was called the NCDC. Should the URL for this resource change in the future, you can search for "NCEI weather API" to find the updated one.*
#
# ## Background on the weather data
#
# Data meanings:
# - `AWND`: average wind speed
# - `PRCP`: precipitation in millimeters
# - `SNOW`: snowfall in millimeters
# - `SNWD`: snow depth in millimeters
# - `TMAX`: maximum daily temperature in Celsius
# - `TMIN`: minimum daily temperature in Celsius
#
# ## Setup

# %%
# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/dirty_data.csv

# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/fb_2018.csv

# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/fb_week_of_may_20_per_minute.csv

# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/melted_stock_data.csv

# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/nyc_weather_2018.csv

# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/stocks.db

# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/weather.db

# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/weather_by_station.csv

# !wget https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/weather_stations.csv

# !mkdir data

# !mv *.* data
# Out:
# --2024-10-02 12:35:16--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/dirty_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46422 (45K) [text/plain]
# Saving to: ‘dirty_data.csv’
#
# dirty_data.csv      100%[===================>]  45.33K  --.-KB/s    in 0.001s
#
# 2024-10-02 12:35:16 (35.6 MB/s) - ‘dirty_data.csv’ saved [46422/46422]
#
# --2024-10-02 12:35:16--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/fb_2018.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12008 (12K) [text/plain]
# Saving to: ‘fb_2018.csv’
#
# fb_2018.csv         100%[===================>]  11.73K  --.-KB/s    in 0s
#
# 2024-10-02 12:35:17 (66.8 MB/s) - ‘fb_2018.csv’ saved [12008/12008]
#
# --2024-10-02 12:35:17--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/fb_week_of_may_20_per_minute.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 105385 (103K) [text/plain]
# Saving to: ‘fb_week_of_may_20_per_minute.csv’
#
# fb_week_of_may_20_p 100%[===================>] 102.92K  --.-KB/s    in 0.004s
#
# 2024-10-02 12:35:17 (28.6 MB/s) - ‘fb_week_of_may_20_per_minute.csv’ saved [105385/105385]
#
# --2024-10-02 12:35:17--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/melted_stock_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 214127 (209K) [text/plain]
# Saving to: ‘melted_stock_data.csv’
#
# melted_stock_data.c 100%[===================>] 209.11K  --.-KB/s    in 0.006s
#
# 2024-10-02 12:35:17 (36.8 MB/s) - ‘melted_stock_data.csv’ saved [214127/214127]
#
# --2024-10-02 12:35:17--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/nyc_weather_2018.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4359847 (4.2M) [text/plain]
# Saving to: ‘nyc_weather_2018.csv’
#
# nyc_weather_2018.cs 100%[===================>]   4.16M  --.-KB/s    in 0.03s
#
# 2024-10-02 12:35:17 (152 MB/s) - ‘nyc_weather_2018.csv’ saved [4359847/4359847]
#
# --2024-10-02 12:35:17--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/stocks.db
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 311296 (304K) [application/octet-stream]
# Saving to: ‘stocks.db’
#
# stocks.db           100%[===================>] 304.00K  --.-KB/s    in 0.006s
#
# 2024-10-02 12:35:17 (53.6 MB/s) - ‘stocks.db’ saved [311296/311296]
#
# --2024-10-02 12:35:17--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/weather.db
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4911104 (4.7M) [application/octet-stream]
# Saving to: ‘weather.db’
#
# weather.db          100%[===================>]   4.68M  --.-KB/s    in 0.03s
#
# 2024-10-02 12:35:18 (176 MB/s) - ‘weather.db’ saved [4911104/4911104]
#
# --2024-10-02 12:35:18--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/weather_by_station.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5429018 (5.2M) [text/plain]
# Saving to: ‘weather_by_station.csv’
#
# weather_by_station. 100%[===================>]   5.18M  --.-KB/s    in 0.05s
#
# 2024-10-02 12:35:18 (94.8 MB/s) - ‘weather_by_station.csv’ saved [5429018/5429018]
#
# --2024-10-02 12:35:18--  https://raw.githubusercontent.com/stefmolin/Hands-On-Data-Analysis-with-Pandas-2nd-edition/master/ch_04/data/weather_stations.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19523 (19K) [text/plain]
# Saving to: ‘weather_stations.csv’
#
# weather_stations.cs 100%[===================>]  19.07K  --.-KB/s    in 0.003s
#
# 2024-10-02 12:35:18 (6.28 MB/s) - ‘weather_stations.csv’ saved [19523/19523]

# %%
import numpy as np
import pandas as pd

weather = pd.read_csv('data/nyc_weather_2018.csv', parse_dates=['date'])
weather.head()
# Out:
#         date datatype            station attributes  value
# 0 2018-01-01     PRCP  GHCND:US1CTFR0039       ,,N,    0.0
# 1 2018-01-01     PRCP  GHCND:US1NJBG0015       ,,N,    0.0
# 2 2018-01-01     SNOW  GHCND:US1NJBG0015       ,,N,    0.0
# 3 2018-01-01     PRCP  GHCND:US1NJBG0017       ,,N,    0.0
# 4 2018-01-01     SNOW  GHCND:US1NJBG0017       ,,N,    0.0

# %%
fb = pd.read_csv('data/fb_2018.csv', index_col='date', parse_dates=True)
fb.head()
# Out:
#               open    high       low   close    volume
# date
# 2018-01-02  177.68  181.58  177.5500  181.42  18151903
# 2018-01-03  181.88  184.78  181.3300  184.67  16886563
# 2018-01-04  184.90  186.21  184.0996  184.33  13880896
# 2018-01-05  185.59  186.90  184.9300  186.85  13574535
# 2018-01-08  187.20  188.90  186.3300  188.28  17994726

# %% [markdown]
# ## Arithmetic and statistics
# We already saw that we can use mathematical operators like `+` and `/` with dataframes directly. However, we can also use methods, which allow us to specify the axis to perform the calculation over. By default, this is per column. Let's find the Z-scores for the volume traded and look at the days where this was more than 3 standard deviations from the mean:

# %%
#2단계 분리
df1=fb.assign(
    abs_z_score_volume=lambda x: \
        ((x.volume-x.volume.mean())/ (x.volume.std()) ).abs()
)
df1.loc[df1.abs_z_score_volume > 3,:] #loc으로 필터링
# Out:
#               open    high     low   close     volume  abs_z_score_volume
# date
# 2018-03-19  177.01  177.17  170.06  172.56   88140060            3.145078
# 2018-03-20  167.47  170.20  161.95  168.15  129851768            5.315169
# 2018-03-21  164.80  173.40  163.30  169.39  106598834            4.105413
# 2018-03-26  160.82  161.10  149.02  160.06  126116634            5.120845
# 2018-07-26  174.89  180.13  173.75  176.26  169803668            7.393705

# %%
fb.assign(
    abs_z_score_volume=lambda x: \
        ((x.volume-x.volume.mean())/ (x.volume.std()) ).abs()
).query('abs_z_score_volume > 3')
#밑의 결과와 동일
# Out:
#               open    high     low   close     volume  abs_z_score_volume
# date
# 2018-03-19  177.01  177.17  170.06  172.56   88140060            3.145078
# 2018-03-20  167.47  170.20  161.95  168.15  129851768            5.315169
# 2018-03-21  164.80  173.40  163.30  169.39  106598834            4.105413
# 2018-03-26  160.82  161.10  149.02  160.06  126116634            5.120845
# 2018-07-26  174.89  180.13  173.75  176.26  169803668            7.393705

# %%
fb.assign(
    abs_z_score_volume=lambda x: \
        x.volume.sub(x.volume.mean()).div(x.volume.std()).abs()
).query('abs_z_score_volume > 3')
# assign :  abs_z_score_volume 열 추가
# query : 필터링
# sub() :  volume 열의 각 값에서 평균값 빼는 작업
# div() :  앞에서 계산된 각 값(평균과 차이)을 표준편차로 나누어 Z-점수 계산
# Out:
#               open    high     low   close     volume  abs_z_score_volume
# date
# 2018-03-19  177.01  177.17  170.06  172.56   88140060            3.145078
# 2018-03-20  167.47  170.20  161.95  168.15  129851768            5.315169
# 2018-03-21  164.80  173.40  163.30  169.39  106598834            4.105413
# 2018-03-26  160.82  161.10  149.02  160.06  126116634            5.120845
# 2018-07-26  174.89  180.13  173.75  176.26  169803668            7.393705

# %% [markdown]
# We can use `rank()` and `pct_change()` to see which days had the largest change in volume traded from the day before:

# %%
fb.assign(
    volume_pct_change=fb.volume.pct_change(),
    pct_change_rank=lambda x: \
        x.volume_pct_change.abs().rank(ascending=False)
)
# Out:
#               open    high       low   close    volume  volume_pct_change  \
# date
# 2018-01-02  177.68  181.58  177.5500  181.42  18151903                NaN
# 2018-01-03  181.88  184.78  181.3300  184.67  16886563          -0.069708
# 2018-01-04  184.90  186.21  184.0996  184.33  13880896          -0.177992
# 2018-01-05  185.59  186.90  184.9300  186.85  13574535          -0.022071
# 2018-01-08  187.20  188.90  186.3300  188.28  17994726           0.325624
# ...            ...     ...       ...     ...       ...                ...
# 2018-12-24  123.10  129.74  123.0200  124.06  22066002          -0.612207
# 2018-12-26  126.00  134.24  125.8900  134.18  39723370           0.800207
# 2018-12-27  132.44  134.99  129.6700  134.52  31202509          -0.214505
# 2018-12-28  135.34  135.92  132.2000  133.20  22627569          -0.274816
# 2018-12-31  134.45  134.64  129.9500  131.09  24625308           0.088288
#
#             pct_change_rank
# date
# 2018-01-02              NaN
# 2018-01-03            202.0
# 2018-01-04            138.0
# 2018-01-05            234.0
# 2018-01-08             64.0
# ...                     ...
# 2018-12-24             22.0
# 2018-12-26             13.0
# 2018-12-27            116.0
# 2018-12-28             80.0
# 2018-12-31            190.0
#
# [251 rows x 7 columns]

# %%
fb.assign(
    volume_pct_change=fb.volume.pct_change(),
    pct_change_rank=lambda x: \
        x.volume_pct_change.abs().rank(ascending=False)
).nsmallest(5, 'pct_change_rank')

# pct_change() :  이전 값과 비교해 백분율 변화(percentage change)를 계산
# rank(ascending=False): 내림차순 순위
# nsmallest(5, 'pct_change_rank'): pct_change_rank 열에서 가장 작은 값(가장 큰 변화를 가진 값) 기준으로 상위 5개의 행
# Out:
#               open    high     low   close     volume  volume_pct_change  \
# date
# 2018-01-12  178.06  181.48  177.40  179.37   77551299           7.087876
# 2018-03-19  177.01  177.17  170.06  172.56   88140060           2.611789
# 2018-07-26  174.89  180.13  173.75  176.26  169803668           1.628841
# 2018-09-21  166.64  167.25  162.81  162.93   45994800           1.428956
# 2018-03-26  160.82  161.10  149.02  160.06  126116634           1.352496
#
#             pct_change_rank
# date
# 2018-01-12              1.0
# 2018-03-19              2.0
# 2018-07-26              3.0
# 2018-09-21              4.0
# 2018-03-26              5.0

# %% [markdown]
# January 12th was when the news that Facebook changed its news feed product to focus more on content from a users' friends over the brands they follow. Given that Facebook's advertising is a key component of its business ([nearly 89% in 2017](https://www.investopedia.com/ask/answers/120114/how-does-facebook-fb-make-money.asp)), many shares were sold and the price dropped in panic:

# %%
fb['2018-01-11':'2018-01-12'] # 페이스북의 변화
# Out:
#               open    high     low   close    volume
# date
# 2018-01-11  188.40  188.40  187.38  187.77   9588587
# 2018-01-12  178.06  181.48  177.40  179.37  77551299

# %% [markdown]
# Throughout 2018, Facebook's stock price never had a low above $215:

# %%
(fb > 215).any()
# any() : 각 열에 대해 하나라도 True 값이 있는지 확인
# Out:
# open       True
# high       True
# low       False
# close      True
# volume     True
# dtype: bool

# %% [markdown]
# Facebook's OHLC (open, high, low, and close) prices all had at least one day they were at $215 or less:

# %%
(fb > 215).all()
# all() : 각 열에서 모든 값이 True인지 확인
# Out:
# open      False
# high      False
# low       False
# close     False
# volume     True
# dtype: bool

# %% [markdown]
# ## Binning
# When working with volume traded, we may be interested in ranges of volume rather than the exact values. No two days have the same volume traded:

# %%
fb.volume.value_counts() #모든 값이 1개로 카운팅 > 연속형
# Out:
# volume
# 18151903    1
# 24300600    1
# 21518006    1
# 19578514    1
# 16894083    1
#            ..
# 23282811    1
# 21071403    1
# 21207848    1
# 15646744    1
# 24625308    1
# Name: count, Length: 251, dtype: int64

# %%
(fb.volume.value_counts() > 1).sum()
# Out:
# 0

# %% [markdown]
# We can use `pd.cut()` to create 3 bins of even range in volume traded and name them. Then we can work with low, medium, and high volume traded categories:

# %%
volume_binned = pd.cut(fb.volume, bins=3, labels=['low', 'med', 'high'])
#pd.cut() : 연속형 데이터를 주어진 구간(bins)으로 나눔
#low category에 쏠려있음
volume_binned.value_counts()
# Out:
# volume
# low     240
# med       8
# high      3
# Name: count, dtype: int64

# %% [markdown]
# Let's look at the days with high trading volume:

# %%
volume_binned
# Out:
# date
# 2018-01-02    low
# 2018-01-03    low
# 2018-01-04    low
# 2018-01-05    low
# 2018-01-08    low
#              ...
# 2018-12-24    low
# 2018-12-26    low
# 2018-12-27    low
# 2018-12-28    low
# 2018-12-31    low
# Name: volume, Length: 251, dtype: category
# Categories (3, object): ['low' < 'med' < 'high']

# %%
fb[volume_binned == 'high'].sort_values('volume', ascending=False)
# Out:
#               open    high     low   close     volume
# date
# 2018-07-26  174.89  180.13  173.75  176.26  169803668
# 2018-03-20  167.47  170.20  161.95  168.15  129851768
# 2018-03-26  160.82  161.10  149.02  160.06  126116634

# %% [markdown]
# July 25th Facebook announced disappointing user growth and the stock tanked in the after hours:

# %%
fb['2018-07-25':'2018-07-26']
# Out:
#                open    high     low   close     volume
# date
# 2018-07-25  215.715  218.62  214.27  217.50   64592585
# 2018-07-26  174.890  180.13  173.75  176.26  169803668

# %% [markdown]
# Cambridge Analytica scandal broke on Saturday, March 17th, so we look at the Monday after for the numbers:

# %%
fb['2018-03-16':'2018-03-20']
# Out:
#               open    high     low   close     volume
# date
# 2018-03-16  184.49  185.33  183.41  185.09   24403438
# 2018-03-19  177.01  177.17  170.06  172.56   88140060
# 2018-03-20  167.47  170.20  161.95  168.15  129851768

# %% [markdown]
# Since most days have similar volume, but a few are very large, we have very wide bins. Most of the data is in the low bin.
#
# *Note: visualizations will be covered in chapters 5 and 6.*

# %%
pip install vpython
# Out:
# Collecting vpython
#   Downloading vpython-7.6.5-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.7 kB)
# Collecting jupyter (from vpython)
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting jupyter-server-proxy (from vpython)
#   Downloading jupyter_server_proxy-4.4.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting jupyterlab-vpython>=3.1.8 (from vpython)
#   Downloading jupyterlab_vpython-3.1.8-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vpython) (1.26.4)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from vpython) (5.5.6)
# Collecting autobahn<27,>=22.6.1 (from vpython)
#   Downloading autobahn-24.4.2-py2.py3-none-any.whl.metadata (18 kB)
# Collecting txaio>=21.2.1 (from autobahn<27,>=22.6.1->vpython)
#   Downloading txaio-23.1.1-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: cryptography>=3.4.6 in /usr/local/lib/python3.10/dist-packages (from autobahn<27,>=22.6.1->vpython) (43.0.1)
# Collecting hyperlink>=21.0.0 (from autobahn<27,>=22.6.1->vpython)
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from autobahn<27,>=22.6.1->vpython) (71.0.4)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel->vpython) (0.2.0)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->vpython) (7.34.0)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->vpython) (5.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel->vpython) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel->vpython) (6.3.3)
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (from jupyter->vpython) (6.5.5)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.10/dist-packages (from jupyter->vpython) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from jupyter->vpython) (6.5.4)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from jupyter->vpython) (7.7.1)
# Collecting jupyterlab (from jupyter->vpython)
#   Downloading jupyterlab-4.2.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from jupyter-server-proxy->vpython) (3.10.5)
# Requirement already satisfied: jupyter-server>=1.24.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server-proxy->vpython) (1.24.0)
# Collecting simpervisor>=1.0.0 (from jupyter-server-proxy->vpython)
#   Downloading simpervisor-1.0.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.4.6->autobahn<27,>=22.6.1->vpython) (1.17.1)
# Requirement already satisfied: idna>=2.5 in /usr/local/lib/python3.10/dist-packages (from hyperlink>=21.0.0->autobahn<27,>=22.6.1->vpython) (3.10)
# Collecting jedi>=0.16 (from ipython>=5.0.0->ipykernel->vpython)
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->vpython) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->vpython) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->vpython) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->vpython) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->vpython) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->vpython) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->vpython) (4.9.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->vpython) (3.7.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->vpython) (23.1.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->vpython) (3.1.4)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->vpython) (5.7.2)
# Requirement already satisfied: nbformat>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->vpython) (5.10.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->vpython) (24.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->vpython) (0.21.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->vpython) (24.0.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->vpython) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->vpython) (0.18.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->vpython) (1.8.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel->vpython) (2.8.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->vpython) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->vpython) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->vpython) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->vpython) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->vpython) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->vpython) (0.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->vpython) (2.1.5)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->vpython) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->vpython) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->vpython) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->vpython) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->vpython) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->vpython) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->vpython) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->vpython) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->vpython) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->vpython) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jupyter-server-proxy->vpython) (4.0.3)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter->vpython) (3.6.9)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter->vpython) (3.0.13)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter->vpython)
#   Downloading async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting httpx>=0.25.0 (from jupyterlab->jupyter->vpython)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting ipykernel (from vpython)
#   Downloading ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter->vpython)
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Collecting jupyter-server>=1.24.0 (from jupyter-server-proxy->vpython)
#   Downloading jupyter_server-2.14.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab->jupyter->vpython)
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.10/dist-packages (from jupyterlab->jupyter->vpython) (0.2.4)
# Requirement already satisfied: tomli>=1.2.2 in /usr/local/lib/python3.10/dist-packages (from jupyterlab->jupyter->vpython) (2.0.1)
# Collecting comm>=0.1.1 (from ipykernel->vpython)
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.10/dist-packages (from ipykernel->vpython) (1.6.6)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from ipykernel->vpython) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ipykernel->vpython) (5.9.5)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server>=1.24.0->jupyter-server-proxy->vpython) (4.3.6)
# Collecting jupyter-client (from jupyter-console->jupyter->vpython)
#   Downloading jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# Collecting jupyter-events>=0.9.0 (from jupyter-server>=1.24.0->jupyter-server-proxy->vpython)
#   Downloading jupyter_events-0.10.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server>=1.24.0->jupyter-server-proxy->vpython)
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting overrides>=5.0 (from jupyter-server>=1.24.0->jupyter-server-proxy->vpython)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-client (from jupyter-console->jupyter->vpython)
#   Downloading jupyter_client-7.4.9-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->vpython) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.24.0->jupyter-server-proxy->vpython) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.24.0->jupyter-server-proxy->vpython) (1.2.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->jupyter-server>=1.24.0->jupyter-server-proxy->vpython) (21.2.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from async-lru>=1.0.0->jupyterlab->jupyter->vpython) (4.12.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.4.6->autobahn<27,>=22.6.1->vpython) (2.22)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter->vpython) (2024.8.30)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab->jupyter->vpython)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->vpython)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->vpython) (0.8.4)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->vpython) (4.23.0)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->vpython)
#   Downloading python_json_logger-2.0.7-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.10/dist-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->vpython) (6.0.2)
# Requirement already satisfied: referencing in /usr/local/lib/python3.10/dist-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->vpython) (0.35.1)
# Collecting rfc3339-validator (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->vpython)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->vpython)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->vpython) (2.16.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->vpython)
#   Downloading json5-0.9.25-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->vpython) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.2.0->jupyter-server>=1.24.0->jupyter-server-proxy->vpython) (2.20.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=5.0.0->ipykernel->vpython) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->vpython) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.1->jupyter-client->ipykernel->vpython) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->jupyter->vpython) (2.6)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->jupyter->vpython) (0.5.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->vpython) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->vpython) (0.20.0)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->vpython)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->vpython)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->vpython)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->vpython)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->vpython) (24.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->vpython) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->vpython) (2.2.3)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->vpython)
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->vpython)
#   Downloading types_python_dateutil-2.9.0.20240906-py3-none-any.whl.metadata (1.9 kB)
# Downloading vpython-7.6.5-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 63.4 MB/s eta 0:00:00
# Downloading autobahn-24.4.2-py2.py3-none-any.whl (666 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 667.0/667.0 kB 46.1 MB/s eta 0:00:00
# Downloading jupyterlab_vpython-3.1.8-py3-none-any.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 82.3 MB/s eta 0:00:00
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading jupyter_server_proxy-4.4.0-py3-none-any.whl (37 kB)
# Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 5.6 MB/s eta 0:00:00
# Downloading simpervisor-1.0.0-py3-none-any.whl (8.3 kB)
# Downloading txaio-23.1.1-py2.py3-none-any.whl (30 kB)
# Downloading jupyterlab-4.2.5-py3-none-any.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 84.2 MB/s eta 0:00:00
# Downloading ipykernel-6.29.5-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 9.4 MB/s eta 0:00:00
# Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading jupyter_server-2.14.2-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 27.3 MB/s eta 0:00:00
# Downloading jupyter_client-7.4.9-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 11.1 MB/s eta 0:00:00
# Downloading async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.8 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.8 MB/s eta 0:00:00
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# Downloading jupyter_events-0.10.0-py3-none-any.whl (18 kB)
# Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 4.0 MB/s eta 0:00:00
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 4.7 MB/s eta 0:00:00
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading json5-0.9.25-py3-none-any.whl (30 kB)
# Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.7 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 5.3 MB/s eta 0:00:00
# Downloading types_python_dateutil-2.9.0.20240906-py3-none-any.whl (9.7 kB)
# Installing collected packages: uri-template, types-python-dateutil, txaio, simpervisor, rfc3986-validator, rfc3339-validator, python-json-logger, overrides, jupyterlab-vpython, jsonpointer, json5, jedi, hyperlink, h11, fqdn, comm, async-lru, jupyter-server-terminals, jupyter-client, httpcore, arrow, isoduration, ipykernel, httpx, autobahn, jupyter-events, jupyter-server, jupyterlab-server, jupyter-server-proxy, jupyter-lsp, jupyterlab, jupyter, vpython
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.5.6
#     Uninstalling ipykernel-5.5.6:
#       Successfully uninstalled ipykernel-5.5.6
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter-server 1.24.0
#     Uninstalling jupyter-server-1.24.0:
#       Successfully uninstalled jupyter-server-1.24.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel==5.5.6, but you have ipykernel 6.29.5 which is incompatible.
# Successfully installed arrow-1.3.0 async-lru-2.0.4 autobahn-24.4.2 comm-0.2.2 fqdn-1.5.1 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 hyperlink-21.0.0 ipykernel-6.29.5 isoduration-20.11.0 jedi-0.19.1 json5-0.9.25 jsonpointer-3.0.0 jupyter-1.1.1 jupyter-client-7.4.9 jupyter-events-0.10.0 jupyter-lsp-2.2.5 jupyter-server-2.14.2 jupyter-server-proxy-4.4.0 jupyter-server-terminals-0.5.3 jupyterlab-4.2.5 jupyterlab-server-2.27.3 jupyterlab-vpython-3.1.8 overrides-7.7.0 python-json-logger-2.0.7 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 simpervisor-1.0.0 txaio-23.1.1 types-python-dateutil-2.9.0.20240906 uri-template-1.3.0 vpython-7.6.5

# %%
from visual_aids.misc_viz import low_med_high_bins_viz

low_med_high_bins_viz(
    fb, 'volume', ylabel='volume traded',
    title='Daily Volume Traded of Facebook Stock in 2018 (with bins)'
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-8e4e7c199a97> in <cell line: 1>()
# ----> 1 from visual_aids.misc_viz import low_med_high_bins_viz
#       2
#       3 low_med_high_bins_viz(
#       4     fb, 'volume', ylabel='volume traded',
#       5     title='Daily Volume Traded of Facebook Stock in 2018 (with bins)'
#
# ModuleNotFoundError: No module named 'visual_aids'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# If we split using quantiles, the bins will have roughly the same number of observations. For this, we use `qcut()`. We will make 4 quartiles:

# %%
volume_qbinned = pd.qcut(fb.volume, q=4, labels=['q1', 'q2', 'q3', 'q4'])
# pd.qcut(): 데이터를 지정된 수의 동일한 크기로 나누어 각 구간에 대한 레이블을 생성
# pd.cut과 다른 결과
volume_qbinned.value_counts()
# Out:
# volume
# q1    63
# q2    63
# q4    63
# q3    62
# Name: count, dtype: int64

# %% [markdown]
# Notice the bins don't cover ranges of the same size anymore:

# %%
from visual_aids.misc_viz import quartile_bins_viz

quartile_bins_viz(
    fb, 'volume', ylabel='volume traded',
    title='Daily Volume Traded of Facebook Stock in 2018 (with quartile bins)'
)
# Out:
# <AxesSubplot:title={'center':'Daily Volume Traded of Facebook Stock in 2018 (with quartile bins)'}, ylabel='volume traded'>

# %% [markdown]
# ## Applying Functions
# We can use the `apply()` method to run the same operation on all columns (or rows) of the dataframe. First, let's isolate the weather observations from the Central Park station and pivot the data:

# %%
weather
# Out:
#             date datatype            station attributes  value
# 0     2018-01-01     PRCP  GHCND:US1CTFR0039       ,,N,    0.0
# 1     2018-01-01     PRCP  GHCND:US1NJBG0015       ,,N,    0.0
# 2     2018-01-01     SNOW  GHCND:US1NJBG0015       ,,N,    0.0
# 3     2018-01-01     PRCP  GHCND:US1NJBG0017       ,,N,    0.0
# 4     2018-01-01     SNOW  GHCND:US1NJBG0017       ,,N,    0.0
# ...          ...      ...                ...        ...    ...
# 78775 2018-12-31     WDF5  GHCND:USW00094789       ,,W,  130.0
# 78776 2018-12-31     WSF2  GHCND:USW00094789       ,,W,    9.8
# 78777 2018-12-31     WSF5  GHCND:USW00094789       ,,W,   12.5
# 78778 2018-12-31     WT01  GHCND:USW00094789       ,,W,    1.0
# 78779 2018-12-31     WT02  GHCND:USW00094789       ,,W,    1.0
#
# [78780 rows x 5 columns]

# %%
weather\
    .query('station == "GHCND:USW00094728"')
# Out:
#             date datatype            station attributes  value
# 189   2018-01-01     AWND  GHCND:USW00094728       ,,W,    3.5
# 190   2018-01-01     PRCP  GHCND:USW00094728   ,,W,2400    0.0
# 191   2018-01-01     SNOW  GHCND:USW00094728       ,,W,    0.0
# 192   2018-01-01     SNWD  GHCND:USW00094728  T,,W,2400    0.0
# 193   2018-01-01     TMAX  GHCND:USW00094728   ,,W,2400   -7.1
# ...          ...      ...                ...        ...    ...
# 78744 2018-12-31     SNOW  GHCND:USW00094728       ,,W,    0.0
# 78745 2018-12-31     SNWD  GHCND:USW00094728   ,,W,2400    0.0
# 78746 2018-12-31     TMAX  GHCND:USW00094728   ,,W,2400    8.9
# 78747 2018-12-31     TMIN  GHCND:USW00094728   ,,W,2400    2.2
# 78748 2018-12-31     WT01  GHCND:USW00094728       ,,W,    1.0
#
# [3503 rows x 5 columns]

# %%
central_park_weather = weather\
    .query('station == "GHCND:USW00094728"')\
    .pivot(index='date', columns='datatype', values='value') #datatype 변수 > wide

# %%
central_park_weather.head()
# Out:
# datatype    AWND  PRCP   SNOW   SNWD  TMAX  TMIN   WDF2   WDF5  WSF2  WSF5  \
# date
# 2018-01-01   3.5   0.0    0.0    0.0  -7.1 -13.8  300.0  300.0   6.7  11.2
# 2018-01-02   3.6   0.0    0.0    0.0  -3.2 -10.5  260.0  250.0   7.2  12.5
# 2018-01-03   1.4   0.0    0.0    0.0  -1.0  -8.8  260.0  270.0   6.3   9.8
# 2018-01-04   5.6  19.3  249.0   30.0  -1.6  -7.1  310.0  310.0  10.7  19.2
# 2018-01-05   5.8   0.0    0.0  180.0  -7.1 -12.7  280.0  280.0   9.4  15.7
#
# datatype    WT01  WT02  WT03  WT06  WT08
# date
# 2018-01-01   NaN   NaN   NaN   NaN   NaN
# 2018-01-02   NaN   NaN   NaN   NaN   NaN
# 2018-01-03   NaN   NaN   NaN   NaN   NaN
# 2018-01-04   1.0   1.0   NaN   NaN   1.0
# 2018-01-05   NaN   NaN   NaN   NaN   NaN

# %% [markdown]
# Let's calculate the Z-scores of the TMIN, TMAX, and PRCP observations in Central Park in October 2018:

# %%
central_park_weather\
    .loc['2018-10', ['TMIN', 'TMAX', 'PRCP']] # 10월 데이터
# Out:
# datatype    TMIN  TMAX  PRCP
# date
# 2018-10-01  17.2  24.4   0.0
# 2018-10-02  18.3  25.0  17.5
# 2018-10-03  17.2  23.3   0.0
# 2018-10-04  16.1  24.4   1.0
# 2018-10-05  15.6  21.7   0.0
# 2018-10-06  17.2  20.0   0.0
# 2018-10-07  19.4  26.1   0.0
# 2018-10-08  17.8  23.3   0.0
# 2018-10-09  18.9  25.0   0.0
# 2018-10-10  21.7  26.7   0.0
# 2018-10-11  20.6  25.0  21.3
# 2018-10-12  10.6  20.0  10.9
# 2018-10-13   7.8  12.8   2.5
# 2018-10-14   8.3  14.4   0.0
# 2018-10-15  11.1  20.0   1.3
# 2018-10-16   8.3  15.6   0.3
# 2018-10-17   7.8  16.1   0.0
# 2018-10-18   5.6  10.0   0.0
# 2018-10-19   6.1  15.6   0.0
# 2018-10-20  10.6  16.7   1.5
# 2018-10-21   3.9  10.6   0.0
# 2018-10-22   3.9  10.0   0.0
# 2018-10-23   9.4  17.2   0.0
# 2018-10-24   6.7  12.2   0.0
# 2018-10-25   4.4  10.6   0.0
# 2018-10-26   3.3  10.0   0.0
# 2018-10-27   6.7  10.6  32.3
# 2018-10-28   7.2  11.1   1.8
# 2018-10-29   8.3  13.3   0.8
# 2018-10-30   5.6  12.8   0.0
# 2018-10-31   6.7  17.8   0.0

# %%
central_park_weather\
    .loc['2018-10', ['TMIN', 'TMAX', 'PRCP']]\
    .apply(lambda x: x.sub(x.mean()).div(x.std())) # z score
# Out:
# datatype        TMIN      TMAX      PRCP
# date
# 2018-10-01  1.065152  1.203293 -0.394438
# 2018-10-02  1.255418  1.307830  1.951865
# 2018-10-03  1.065152  1.011643 -0.394438
# 2018-10-04  0.874887  1.203293 -0.260364
# 2018-10-05  0.788402  0.732879 -0.394438
# 2018-10-06  1.065152  0.436693 -0.394438
# 2018-10-07  1.445683  1.499480 -0.394438
# 2018-10-08  1.168933  1.011643 -0.394438
# 2018-10-09  1.359199  1.307830 -0.394438
# 2018-10-10  1.843511  1.604016 -0.394438
# 2018-10-11  1.653246  1.307830  2.461348
# 2018-10-12 -0.076441  0.436693  1.066973
# 2018-10-13 -0.560753 -0.817745 -0.059252
# 2018-10-14 -0.474269 -0.538981 -0.394438
# 2018-10-15  0.010043  0.436693 -0.220142
# 2018-10-16 -0.474269 -0.329908 -0.354216
# 2018-10-17 -0.560753 -0.242794 -0.394438
# 2018-10-18 -0.941284 -1.305582 -0.394438
# 2018-10-19 -0.854800 -0.329908 -0.394438
# 2018-10-20 -0.076441 -0.138258 -0.193327
# 2018-10-21 -1.235331 -1.201045 -0.394438
# 2018-10-22 -1.235331 -1.305582 -0.394438
# 2018-10-23 -0.284003 -0.051144 -0.394438
# 2018-10-24 -0.751019 -0.922281 -0.394438
# 2018-10-25 -1.148847 -1.201045 -0.394438
# 2018-10-26 -1.339112 -1.305582 -0.394438
# 2018-10-27 -0.751019 -1.201045  3.936167
# 2018-10-28 -0.664534 -1.113931 -0.153104
# 2018-10-29 -0.474269 -0.730631 -0.287179
# 2018-10-30 -0.941284 -0.817745 -0.394438
# 2018-10-31 -0.751019  0.053392 -0.394438

# %%
oct_weather_z_scores = central_park_weather\
    .loc['2018-10', ['TMIN', 'TMAX', 'PRCP']]\
    .apply(lambda x: x.sub(x.mean()).div(x.std()))
oct_weather_z_scores.describe().T
# PRCP max 높은 수치
# Out:
#           count          mean  std       min       25%       50%       75%  \
# datatype
# TMIN       31.0 -1.790682e-16  1.0 -1.339112 -0.751019 -0.474269  1.065152
# TMAX       31.0  1.951844e-16  1.0 -1.305582 -0.870013 -0.138258  1.011643
# PRCP       31.0  1.038596e-16  1.0 -0.394438 -0.394438 -0.394438 -0.240253
#
#                max
# datatype
# TMIN      1.843511
# TMAX      1.604016
# PRCP      3.936167

# %%
oct_weather_z_scores
# Out:
# datatype        TMIN      TMAX      PRCP
# date
# 2018-10-01  1.065152  1.203293 -0.394438
# 2018-10-02  1.255418  1.307830  1.951865
# 2018-10-03  1.065152  1.011643 -0.394438
# 2018-10-04  0.874887  1.203293 -0.260364
# 2018-10-05  0.788402  0.732879 -0.394438
# 2018-10-06  1.065152  0.436693 -0.394438
# 2018-10-07  1.445683  1.499480 -0.394438
# 2018-10-08  1.168933  1.011643 -0.394438
# 2018-10-09  1.359199  1.307830 -0.394438
# 2018-10-10  1.843511  1.604016 -0.394438
# 2018-10-11  1.653246  1.307830  2.461348
# 2018-10-12 -0.076441  0.436693  1.066973
# 2018-10-13 -0.560753 -0.817745 -0.059252
# 2018-10-14 -0.474269 -0.538981 -0.394438
# 2018-10-15  0.010043  0.436693 -0.220142
# 2018-10-16 -0.474269 -0.329908 -0.354216
# 2018-10-17 -0.560753 -0.242794 -0.394438
# 2018-10-18 -0.941284 -1.305582 -0.394438
# 2018-10-19 -0.854800 -0.329908 -0.394438
# 2018-10-20 -0.076441 -0.138258 -0.193327
# 2018-10-21 -1.235331 -1.201045 -0.394438
# 2018-10-22 -1.235331 -1.305582 -0.394438
# 2018-10-23 -0.284003 -0.051144 -0.394438
# 2018-10-24 -0.751019 -0.922281 -0.394438
# 2018-10-25 -1.148847 -1.201045 -0.394438
# 2018-10-26 -1.339112 -1.305582 -0.394438
# 2018-10-27 -0.751019 -1.201045  3.936167
# 2018-10-28 -0.664534 -1.113931 -0.153104
# 2018-10-29 -0.474269 -0.730631 -0.287179
# 2018-10-30 -0.941284 -0.817745 -0.394438
# 2018-10-31 -0.751019  0.053392 -0.394438

# %% [markdown]
# October 27th rained much more than the rest of the days:

# %%
oct_weather_z_scores.query('PRCP > 3').PRCP
# Out:
# date
# 2018-10-27    3.936167
# Name: PRCP, dtype: float64

# %% [markdown]
# Indeed, this day was much higher than the rest:

# %%
central_park_weather.loc['2018-10', 'PRCP'].describe()
# Out:
# count    31.000000
# mean      2.941935
# std       7.458542
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.150000
# max      32.300000
# Name: PRCP, dtype: float64

# %% [markdown]
# When the function we want to apply isn't vectorized, we can:
# - use `np.vectorize()` to vectorize it (similar to how `map()` works) and then use it with `apply()`
# - use `applymap()` and pass it the non-vectorized function directly
#
# Say we wanted to count the digits of the whole numbers for the Facebook data; `len()` is not vectorized, so we can use `np.vectorize()` or `applymap()`:

# %%
fb.apply(
    lambda x: np.vectorize(lambda y: len(str(np.ceil(y))))(x)
).astype('int64').equals(
    fb.applymap(lambda x: len(str(np.ceil(x))))
)
# Out:
# <ipython-input-37-07c6bad7dc11>:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   fb.applymap(lambda x: len(str(np.ceil(x))))
# True

# %% [markdown]
# A simple operation of addition to each element in a series grows linearly in time complexity when using `iteritems()`, but stays near 0 when using vectorized operations. `iteritems()` and related methods should only be used if there is no vectorized solution:

# %%
import time

import numpy as np
import pandas as pd

np.random.seed(0)

vectorized_results = {}
iteritems_results = {}

for size in [10, 100, 1000, 10000, 100000, 500000, 1000000, 5000000, 10000000]:
    # set of numbers to use
    test = pd.Series(np.random.uniform(size=size))

    # time the vectorized operation
    start = time.time()
    x = test + 10
    end = time.time()
    vectorized_results[size] = end - start

    # time the operation with `iteritems()`
    start = time.time()
    x = []
    for i, v in test.iteritems():
        x.append(v + 10)
    x = pd.Series(x)
    end = time.time()
    iteritems_results[size] = end - start

results = pd.DataFrame(
    [pd.Series(vectorized_results, name='vectorized'), pd.Series(iteritems_results, name='iteritems')]
).T

# plotting
ax = results.plot(title='Time Complexity', color=['blue', 'red'], legend=False)

# formatting
ax.set(xlabel='item size (rows)', ylabel='time (s)')
ax.text(0.5e7, iteritems_results[0.5e7] * .9, 'iteritems()', rotation=34, color='red', fontsize=12, ha='center', va='bottom')
ax.text(0.5e7, vectorized_results[0.5e7], 'vectorized', color='blue', fontsize=12, ha='center', va='bottom')
for spine in ['top', 'right']:
    ax.spines[spine].set_visible(False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-3da5c5027e27> in <cell line: 11>()
#      22     start = time.time()
#      23     x = []
# ---> 24     for i, v in test.iteritems():
#      25         x.append(v + 10)
#      26     x = pd.Series(x)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# AttributeError: 'Series' object has no attribute 'iteritems'

# %% [markdown]
# ## Window Calculations
# *Consult the [`understanding_window_calculations.ipynb`](./understanding_window_calculations.ipynb) notebook for interactive visualizations using widgets to help understand window calculations.*
#
# The `rolling()` method allows us to perform rolling window calculations. We simply specify the window size (3 days here) and follow it with a call to an aggregation function (sum here):

# %%
central_park_weather.loc['2018-10'].assign(
    rolling_PRCP=lambda x: x.PRCP.rolling('3D').sum()
)[['PRCP', 'rolling_PRCP']].head(7).T # 3일 합계
# Out:
# date          2018-10-01  2018-10-02  2018-10-03  2018-10-04  2018-10-05  \
# datatype
# PRCP                 0.0        17.5         0.0         1.0         0.0
# rolling_PRCP         0.0        17.5        17.5        18.5         1.0
#
# date          2018-10-06  2018-10-07
# datatype
# PRCP                 0.0         0.0
# rolling_PRCP         1.0         0.0

# %% [markdown]
# We can also perform the rolling calculations on the entire dataframe at once. This will apply the same aggregation function to each column:

# %%
central_park_weather.loc['2018-10'].rolling('3D').mean().head(7).iloc[:,:6]
# Out:
# datatype        AWND      PRCP  SNOW  SNWD       TMAX       TMIN
# date
# 2018-10-01  0.900000  0.000000   0.0   0.0  24.400000  17.200000
# 2018-10-02  0.900000  8.750000   0.0   0.0  24.700000  17.750000
# 2018-10-03  0.966667  5.833333   0.0   0.0  24.233333  17.566667
# 2018-10-04  0.800000  6.166667   0.0   0.0  24.233333  17.200000
# 2018-10-05  1.033333  0.333333   0.0   0.0  23.133333  16.300000
# 2018-10-06  0.833333  0.333333   0.0   0.0  22.033333  16.300000
# 2018-10-07  1.066667  0.000000   0.0   0.0  22.600000  17.400000

# %% [markdown]
# We can use different aggregation functions per column if we use `agg()` instead. We pass in a dictionary mapping the column to the aggregation to perform on it. Here, we join the result to the original data to see what is happening:

# %%
central_park_weather['2018-10-01':'2018-10-07'].rolling('3D').agg(
    {'TMAX': 'max', 'TMIN': 'min', 'AWND': 'mean', 'PRCP': 'sum'}
).join( # join with original data for comparison
    central_park_weather[['TMAX', 'TMIN', 'AWND', 'PRCP']],
    lsuffix='_rolling'
).sort_index(axis=1) # sort columns so rolling calcs are next to originals
# lsuffix='_rolling': 결합 시 롤링 계산 결과 열에 _rolling 붙임
# Out:
# datatype    AWND  AWND_rolling  PRCP  PRCP_rolling  TMAX  TMAX_rolling  TMIN  \
# date
# 2018-10-01   0.9      0.900000   0.0           0.0  24.4          24.4  17.2
# 2018-10-02   0.9      0.900000  17.5          17.5  25.0          25.0  18.3
# 2018-10-03   1.1      0.966667   0.0          17.5  23.3          25.0  17.2
# 2018-10-04   0.4      0.800000   1.0          18.5  24.4          25.0  16.1
# 2018-10-05   1.6      1.033333   0.0           1.0  21.7          24.4  15.6
# 2018-10-06   0.5      0.833333   0.0           1.0  20.0          24.4  17.2
# 2018-10-07   1.1      1.066667   0.0           0.0  26.1          26.1  19.4
#
# datatype    TMIN_rolling
# date
# 2018-10-01          17.2
# 2018-10-02          17.2
# 2018-10-03          17.2
# 2018-10-04          16.1
# 2018-10-05          15.6
# 2018-10-06          15.6
# 2018-10-07          15.6

# %% [markdown]
# Suppose we reindexed the Facebook stock data as we did with the S&P 500 data in chapter 3. If we were to use rolling calculations on this data, we would be including the values when the market was closed:

# %%
fb
# Out:
#               open    high       low   close    volume
# date
# 2018-01-02  177.68  181.58  177.5500  181.42  18151903
# 2018-01-03  181.88  184.78  181.3300  184.67  16886563
# 2018-01-04  184.90  186.21  184.0996  184.33  13880896
# 2018-01-05  185.59  186.90  184.9300  186.85  13574535
# 2018-01-08  187.20  188.90  186.3300  188.28  17994726
# ...            ...     ...       ...     ...       ...
# 2018-12-24  123.10  129.74  123.0200  124.06  22066002
# 2018-12-26  126.00  134.24  125.8900  134.18  39723370
# 2018-12-27  132.44  134.99  129.6700  134.52  31202509
# 2018-12-28  135.34  135.92  132.2000  133.20  22627569
# 2018-12-31  134.45  134.64  129.9500  131.09  24625308
#
# [251 rows x 5 columns]

# %%
fb_reindexed = fb\
    .reindex(pd.date_range('2018-01-01', '2018-12-31', freq='D'))\
    .assign(
        volume=lambda x: x.volume.fillna(0),
        close=lambda x: x.close.fillna(method='ffill'), #이전 값
        open=lambda x: x.open.combine_first(x.close), # 개장가(open)가 결측값인 경우, 종가(close) 값
        high=lambda x: x.high.combine_first(x.close),
        low=lambda x: x.low.combine_first(x.close)
    )
fb_reindexed.assign(day=lambda x: x.index.day_name()).head(10) #요일 열 추가
# Out:
# <ipython-input-43-1269cadf600b>:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   close=lambda x: x.close.fillna(method='ffill'), #이전 값
#               open    high       low   close      volume        day
# 2018-01-01     NaN     NaN       NaN     NaN         0.0     Monday
# 2018-01-02  177.68  181.58  177.5500  181.42  18151903.0    Tuesday
# 2018-01-03  181.88  184.78  181.3300  184.67  16886563.0  Wednesday
# 2018-01-04  184.90  186.21  184.0996  184.33  13880896.0   Thursday
# 2018-01-05  185.59  186.90  184.9300  186.85  13574535.0     Friday
# 2018-01-06  186.85  186.85  186.8500  186.85         0.0   Saturday
# 2018-01-07  186.85  186.85  186.8500  186.85         0.0     Sunday
# 2018-01-08  187.20  188.90  186.3300  188.28  17994726.0     Monday
# 2018-01-09  188.70  188.80  187.1000  187.87  12393057.0    Tuesday
# 2018-01-10  186.94  187.89  185.6300  187.84  10529894.0  Wednesday

# %% [markdown]
# As of version 1.0, `pandas` supports defining custom windows for rolling calculations, which makes it possible for us to perform rolling calculations on the days the market was open. One way is to make a new class that inherits from `BaseIndexer` and provide the logic for determining the window bounds in the `get_window_bounds()` method (more info [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/computation.html#custom-window-rolling)). For our use case, we can use the `VariableOffsetWindowIndexer` class, which was introduced in version 1.1, to perform rolling calculations over non-fixed time offsets (like business days). Let's perform a three business day rolling calculation on the reindexed Facebook stock data and join it with the reindexed data for comparison:

# %%
from pandas.api.indexers import VariableOffsetWindowIndexer

indexer = VariableOffsetWindowIndexer(
    index=fb_reindexed.index, offset=pd.offsets.BDay(3)
)
fb_reindexed.assign(window_start_day=0).rolling(indexer).agg({
    'window_start_day': lambda x: x.index.min().timestamp(),
    'open': 'mean', 'high': 'max', 'low': 'min',
    'close': 'mean', 'volume': 'sum'
}).join(
    fb_reindexed, lsuffix='_rolling'
).sort_index(axis=1).assign(
    day=lambda x: x.index.day_name(),
    window_start_day=lambda x: pd.to_datetime(x.window_start_day, unit='s')
).head(10)
# Out:
#              close  close_rolling    high  high_rolling       low  \
# 2018-01-01     NaN            NaN     NaN           NaN       NaN
# 2018-01-02  181.42     181.420000  181.58        181.58  177.5500
# 2018-01-03  184.67     183.045000  184.78        184.78  181.3300
# 2018-01-04  184.33     183.473333  186.21        186.21  184.0996
# 2018-01-05  186.85     185.283333  186.90        186.90  184.9300
# 2018-01-06  186.85     186.010000  186.85        186.90  186.8500
# 2018-01-07  186.85     186.220000  186.85        186.90  186.8500
# 2018-01-08  188.28     186.632000  188.90        188.90  186.3300
# 2018-01-09  187.87     187.340000  188.80        188.90  187.1000
# 2018-01-10  187.84     187.538000  187.89        188.90  185.6300
#
#             low_rolling    open  open_rolling      volume  volume_rolling  \
# 2018-01-01          NaN     NaN           NaN         0.0             0.0
# 2018-01-02     177.5500  177.68    177.680000  18151903.0      18151903.0
# 2018-01-03     177.5500  181.88    179.780000  16886563.0      35038466.0
# 2018-01-04     177.5500  184.90    181.486667  13880896.0      48919362.0
# 2018-01-05     181.3300  185.59    184.123333  13574535.0      44341994.0
# 2018-01-06     184.0996  186.85    185.780000         0.0      27455431.0
# 2018-01-07     184.0996  186.85    186.047500         0.0      27455431.0
# 2018-01-08     184.0996  187.20    186.278000  17994726.0      45450157.0
# 2018-01-09     184.9300  188.70    187.038000  12393057.0      43962318.0
# 2018-01-10     185.6300  186.94    187.308000  10529894.0      40917677.0
#
#            window_start_day        day
# 2018-01-01       2018-01-01     Monday
# 2018-01-02       2018-01-01    Tuesday
# 2018-01-03       2018-01-01  Wednesday
# 2018-01-04       2018-01-02   Thursday
# 2018-01-05       2018-01-03     Friday
# 2018-01-06       2018-01-04   Saturday
# 2018-01-07       2018-01-04     Sunday
# 2018-01-08       2018-01-04     Monday
# 2018-01-09       2018-01-05    Tuesday
# 2018-01-10       2018-01-06  Wednesday

# %% [markdown]
# Rolling calculations (`rolling()`) use a sliding window. Expanding calculations (`expanding()`), however, grow in size. These are equivalent to cumulative aggregations like `cumsum()`; however, we can specify the minimum number of periods required to start calculating (default is 1), and we aren't limited to predefined aggregations. Therefore, while there is no method for the cumulative mean, we can calculate it using `expanding()`. Let's calculate the month-to-date average precipiation:

# %%
central_park_weather.loc['2018-06'].assign(
    TOTAL_PRCP=lambda x: x.PRCP.cumsum(),
    AVG_PRCP=lambda x: x.PRCP.expanding().mean()
).head(10)[['PRCP', 'TOTAL_PRCP', 'AVG_PRCP']].T
# x.PRCP.cumsum() : PRCP 열의 누적 합계
# x.PRCP.expanding().mean() : PRCP 열의 확장 평균을 계산
# Out:
# date        2018-06-01  2018-06-02  2018-06-03  2018-06-04  2018-06-05  \
# datatype
# PRCP               6.9        2.00         6.4        4.10        0.00
# TOTAL_PRCP         6.9        8.90        15.3       19.40       19.40
# AVG_PRCP           6.9        4.45         5.1        4.85        3.88
#
# date        2018-06-06  2018-06-07  2018-06-08  2018-06-09  2018-06-10
# datatype
# PRCP          0.000000    0.000000       0.000    0.000000        0.30
# TOTAL_PRCP   19.400000   19.400000      19.400   19.400000       19.70
# AVG_PRCP      3.233333    2.771429       2.425    2.155556        1.97

# %% [markdown]
# We can also use `agg()` to specify aggregations per column. Note that this works with NumPy functions as well. Here, we join the expanding calculations with the original results for comparison:

# %%
central_park_weather['2018-10-01':'2018-10-07'].expanding().agg(
    {'TMAX': np.max, 'TMIN': np.min, 'AWND': np.mean, 'PRCP': np.sum}
).join(
    central_park_weather[['TMAX', 'TMIN', 'AWND', 'PRCP']],
    lsuffix='_expanding'
).sort_index(axis=1)
# Out:
# <ipython-input-46-5fb29ee34634>:1: FutureWarning: The provided callable <function max at 0x78ac5ffab9a0> is currently using Expanding.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   central_park_weather['2018-10-01':'2018-10-07'].expanding().agg(
# <ipython-input-46-5fb29ee34634>:1: FutureWarning: The provided callable <function min at 0x78ac5ffabac0> is currently using Expanding.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   central_park_weather['2018-10-01':'2018-10-07'].expanding().agg(
# <ipython-input-46-5fb29ee34634>:1: FutureWarning: The provided callable <function mean at 0x78ac5d118310> is currently using Expanding.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   central_park_weather['2018-10-01':'2018-10-07'].expanding().agg(
# <ipython-input-46-5fb29ee34634>:1: FutureWarning: The provided callable <function sum at 0x78ac5ffab370> is currently using Expanding.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   central_park_weather['2018-10-01':'2018-10-07'].expanding().agg(
# datatype    AWND  AWND_expanding  PRCP  PRCP_expanding  TMAX  TMAX_expanding  \
# date
# 2018-10-01   0.9        0.900000   0.0             0.0  24.4            24.4
# 2018-10-02   0.9        0.900000  17.5            17.5  25.0            25.0
# 2018-10-03   1.1        0.966667   0.0            17.5  23.3            25.0
# 2018-10-04   0.4        0.825000   1.0            18.5  24.4            25.0
# 2018-10-05   1.6        0.980000   0.0            18.5  21.7            25.0
# 2018-10-06   0.5        0.900000   0.0            18.5  20.0            25.0
# 2018-10-07   1.1        0.928571   0.0            18.5  26.1            26.1
#
# datatype    TMIN  TMIN_expanding
# date
# 2018-10-01  17.2            17.2
# 2018-10-02  18.3            17.2
# 2018-10-03  17.2            17.2
# 2018-10-04  16.1            16.1
# 2018-10-05  15.6            15.6
# 2018-10-06  17.2            15.6
# 2018-10-07  19.4            15.6

# %% [markdown]
# Pandas provides the **`ewm()` method for exponentially weighted moving calculations.** As we saw in chapter 1, we can use the exponentially weighted moving average to smooth the data. Let's compare the rolling mean to the exponentially weighted moving average with the maximum daily temperature. Note that `span` here is the periods to use:

# %%
central_park_weather.assign(
    AVG=lambda x: x.TMAX.rolling('30D').mean(),
    EWMA=lambda x: x.TMAX.ewm(span=30).mean()
).loc['2018-09-29':'2018-10-08', ['TMAX', 'EWMA', 'AVG']].T
# x.TMAX.rolling('30D').mean() : TMAX(최대 기온)의 30일 이동 평균
# x.TMAX.ewm(span=30).mean() : TMAX의 30일 지수 가중 이동 평균을 계산
# Out:
# date      2018-09-29  2018-09-30  2018-10-01  2018-10-02  2018-10-03  \
# datatype
# TMAX       22.200000   21.100000   24.400000   25.000000   23.300000
# EWMA       24.410887   24.197281   24.210360   24.261304   24.199285
# AVG        24.723333   24.573333   24.533333   24.460000   24.163333
#
# date      2018-10-04  2018-10-05  2018-10-06  2018-10-07  2018-10-08
# datatype
# TMAX       24.400000   21.700000   20.000000   26.100000   23.300000
# EWMA       24.212234   24.050154   23.788854   23.937960   23.896802
# AVG        23.866667   23.533333   23.070000   23.143333   23.196667

# %% [markdown]
# *Consult the [`understanding_window_calculations.ipynb`](./understanding_window_calculations.ipynb) notebook for interactive visualizations to help understand window calculations.*
#
# ## Pipes
# Pipes are a way to streamline our `pandas` code and make it more readable and flexible. Using pipes, we can take a nested call like
#
# ```python
# f(g(h(data), 20), x=True)
# ```
#
# and turn it into something more readable:
#
# ```python
# data.pipe(h)\
#     .pipe(g, 20)\
#     .pipe(f, x=True)\
# ```
#
# We can use pipes to apply any function that accepts our data as the first argument and pass in any additional arguments. This makes it easy to chain steps together regardless of whether they are methods or functions:
#
# We can pass any function that will accept the caller of `pipe()` as the first argument:

# %%
def get_info(df):
    return '%d rows, %d columns and max closing Z-score was %d' % (*df.shape, df.close.max())

get_info(fb.loc['2018-Q1'].apply(lambda x: (x - x.mean())/x.std()))\
    == fb.loc['2018-Q1'].apply(lambda x: (x - x.mean())/x.std()).pipe(get_info) # 두 결과가 동일한지 비교
# Out:
# True

# %% [markdown]
# For example, passing `pd.DataFrame.rolling` to `pipe()` is equivalent to calling `rolling()` directly on the dataframe, except we have more flexiblity to change this:

# %%
fb.pipe(pd.DataFrame.rolling, '20D').mean().equals(fb.rolling('20D').mean())
# Out:
# True

# %% [markdown]
# The pipe takes the function passed in and calls it with the object that called `pipe()` as the first argument. Positional and keyword arguments are passed down:

# %%
pd.DataFrame.rolling(fb, '20D').mean().equals(fb.rolling('20D').mean())
# Out:
# True

# %% [markdown]
# We can use a pipe to make a function that we can use for all of our window calculation needs:

# %%
from window_calc import window_calc
window_calc??
# Out:
# Signature: window_calc(df, func, agg_dict, *args, **kwargs)
# Source:
# def window_calc(df, func, agg_dict, *args, **kwargs):
#     """
#     Run a window calculation of your choice on a `DataFrame` object.
#
#     Parameters:
#         - df: The `DataFrame` object to run the calculation on.
#         - func: The window calculation method that takes `df`
#           as the first argument.
#         - agg_dict: Information to pass to `agg()`, could be a
#           dictionary mapping the columns to the aggregation
#           function to use, a string name for the function,
#           or the function itself.
#         - args: Positional arguments to pass to `func`.
#         - kwargs: Keyword arguments to pass to `func`.
#
#     Returns:
#         A new `DataFrame` object.
#     """
#     return df.pipe(func, *args, **kwargs).agg(agg_dict)
# File:      ~/Hands-On-Data-Analysis-with-Pandas-2nd-edition/ch_04/window_calc.py
# Type:      function

# %% [markdown]
# We can use the same interface to calculate various window calculations now. Let's find the expanding median for the Facebook data:

# %%
window_calc(fb, pd.DataFrame.expanding, np.median).head()
# Out:
#               open     high       low    close      volume
# date
# 2018-01-02  177.68  181.580  177.5500  181.420  18151903.0
# 2018-01-03  179.78  183.180  179.4400  183.045  17519233.0
# 2018-01-04  181.88  184.780  181.3300  184.330  16886563.0
# 2018-01-05  183.39  185.495  182.7148  184.500  15383729.5
# 2018-01-08  184.90  186.210  184.0996  184.670  16886563.0

# %% [markdown]
# Using the exponentially weighted moving average requires we pass in a keyword argument:

# %%
window_calc(fb, pd.DataFrame.ewm, 'mean', span=3).head()
# Out:
#                   open        high         low       close        volume
# date
# 2018-01-02  177.680000  181.580000  177.550000  181.420000  1.815190e+07
# 2018-01-03  180.480000  183.713333  180.070000  183.586667  1.730834e+07
# 2018-01-04  183.005714  185.140000  182.372629  184.011429  1.534980e+07
# 2018-01-05  184.384000  186.078667  183.736560  185.525333  1.440299e+07
# 2018-01-08  185.837419  187.534839  185.075110  186.947097  1.625679e+07

# %% [markdown]
# With rolling calculations, we can pass in a positional argument for the window size:

# %%
window_calc(
    central_park_weather.loc['2018-10'],
    pd.DataFrame.rolling,
    {'TMAX': 'max', 'TMIN': 'min', 'AWND': 'mean', 'PRCP': 'sum'},
    '3D'
).head()
# Out:
#             TMAX  TMIN      AWND  PRCP
# date
# 2018-10-01  24.4  17.2  0.900000   0.0
# 2018-10-02  25.0  17.2  0.900000  17.5
# 2018-10-03  25.0  17.2  0.966667  17.5
# 2018-10-04  25.0  16.1  0.800000  18.5
# 2018-10-05  24.4  15.6  1.033333   1.0

# %% [markdown]
# <hr>
# <div style="overflow: hidden; margin-bottom: 10px;">
#     <div style="float: left;">
#          <a href="./1-querying_and_merging.ipynb">
#             <button>&#8592; Previous Notebook</button>
#         </a>
#         <a href="./understanding_window_calculations.ipynb">
#             <button>Understanding Window Calculations</button>
#         </a>
#     </div>
#     <div style="float: right;">
#         <a href="./3-aggregations.ipynb">
#             <button>Next Notebook &#8594;</button>
#         </a>
#     </div>
# </div>
# <hr>
